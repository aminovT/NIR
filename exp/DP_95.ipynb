# %%
import matplotlib.pyplot as plt
from numpy import load

# %%
mod = ['lin_connect' , 'arc_connect']
pf = ['PointFinderWithBias', 'PointFinderInverseWithBias' , 'PointFinderTransportation']
hd = [ 10, 50, 100 , 500, 1000, 2000]
z = 0
for i in hd:
    for m in mod:
        for p in pf:
            z += 1
            if z !=2 and z!=5: 
                path = 'experiments_with_DP_95_/eval/LinearOneLayer{}/{}{}/curve.npz'.format(i,p,m)
                data = load(path)
                print(data['te_err_avg'] , data['te_err_max'] , i , p , m)
            else:
                print(path)
# Out:
# 61.234761904761896 78.03999999999999 10 PointFinderWithBias lin_connect
# experiments_with_DP_95_/eval/LinearOneLayer10/PointFinderWithBiaslin_connect/curve.npz
# 52.35571428571428 60.55 10 PointFinderTransportation lin_connect
# 55.94285714285714 64.97 10 PointFinderWithBias arc_connect
# experiments_with_DP_95_/eval/LinearOneLayer10/PointFinderWithBiasarc_connect/curve.npz
# 49.18047619047619 57.16 10 PointFinderTransportation arc_connect
# 15.397619047619044 23.010000000000005 50 PointFinderWithBias lin_connect
# 11.83 13.219999999999999 50 PointFinderInverseWithBias lin_connect
# 11.103809523809522 11.590000000000003 50 PointFinderTransportation lin_connect
# 13.195714285714283 16.730000000000004 50 PointFinderWithBias arc_connect
# 11.862857142857143 13.14 50 PointFinderInverseWithBias arc_connect
# 13.508095238095237 16.439999999999998 50 PointFinderTransportation arc_connect
# 13.012857142857145 19.049999999999997 100 PointFinderWithBias lin_connect
# 9.254761904761903 9.810000000000002 100 PointFinderInverseWithBias lin_connect
# 9.194285714285714 9.400000000000006 100 PointFinderTransportation lin_connect
# 9.944285714285714 11.349999999999994 100 PointFinderWithBias arc_connect
# 9.354285714285712 10.159999999999997 100 PointFinderInverseWithBias arc_connect
# 10.283809523809525 11.340000000000003 100 PointFinderTransportation arc_connect
# 5.970952380952381 7.989999999999995 500 PointFinderWithBias lin_connect
# 4.92952380952381 5.209999999999994 500 PointFinderInverseWithBias lin_connect
# 4.80952380952381 4.920000000000002 500 PointFinderTransportation lin_connect
# 5.392380952380955 6.290000000000006 500 PointFinderWithBias arc_connect
# 4.9904761904761905 5.239999999999995 500 PointFinderInverseWithBias arc_connect
# 5.063333333333334 5.280000000000001 500 PointFinderTransportation arc_connect
# 4.480476190476192 6.090000000000003 1000 PointFinderWithBias lin_connect
# 3.647619047619049 3.8100000000000023 1000 PointFinderInverseWithBias lin_connect
# 3.541428571428571 3.6400000000000006 1000 PointFinderTransportation lin_connect
# 4.1566666666666645 4.989999999999995 1000 PointFinderWithBias arc_connect
# 3.655714285714287 3.8900000000000006 1000 PointFinderInverseWithBias arc_connect
# 3.7852380952380957 4.010000000000005 1000 PointFinderTransportation arc_connect
# 3.6347619047619033 5.200000000000003 2000 PointFinderWithBias lin_connect
# 2.8828571428571426 2.989999999999995 2000 PointFinderInverseWithBias lin_connect
# 2.813333333333334 2.8599999999999994 2000 PointFinderTransportation lin_connect
# 3.215714285714287 3.799999999999997 2000 PointFinderWithBias arc_connect
# 2.8638095238095245 2.9599999999999937 2000 PointFinderInverseWithBias arc_connect
# 2.935238095238095 3.019999999999996 2000 PointFinderTransportation arc_connect

# %%
mod = ['lin_connect' , 'arc_connect']
pf = ['PointFinderWithBias'] #, 'PointFinderInverseWithBias' , 'PointFinderTransportation']
hd = [  10,50, 100 , 500, 1000, 2000]

for m in mod:
    plt.figure()
    plt.title(m)
    plt.grid()
    for p in pf:
        for i in hd:
            path = 'experiments_with_DP_95_/eval/LinearOneLayer{}/{}{}/curve.npz'.format(i,p,m)
            data = load(path)
            plt.plot(data['tr_err'] , label = str(i))
            
    plt.legend()
    plt.show()

# %%
mod = ['lin_connect' , 'arc_connect']
pf = [ 'PointFinderInverseWithBias' ]#, 'PointFinderTransportation']
hd = [  50, 100 , 500, 1000, 2000]

for m in mod:
    plt.figure()
    plt.title(("WA+"+m))
    plt.grid()
    for p in pf:
        for i in hd:
            path = 'experiments_with_DP_95_/eval/LinearOneLayer{}/{}{}/curve.npz'.format(i,p,m)
            data = load(path)
            plt.plot(data['tr_err'] , label = str(i))
            
    plt.legend()
    plt.show()

# %%
mod = ['lin_connect' , 'arc_connect']
pf = [ 'PointFinderTransportation']
hd = [  10, 50, 100 , 500, 1000, 2000]

for m in mod:
    plt.figure()
    plt.title(("OT+"+m))
    plt.grid()
    for p in pf:
        for i in hd:
            path = 'experiments_with_DP_95_/eval/LinearOneLayer{}/{}{}/curve.npz'.format(i,p,m)
            data = load(path)
            plt.plot(data['tr_err'] , label = str(i))
            
    plt.legend()
    plt.show()

# %%
mod = ['lin_connect' , 'arc_connect']
pf = ['PointFinderWithBias', 'PointFinderInverseWithBias' , 'PointFinderTransportation']
hd = [  50, 100 , 500, 1000, 2000]
for i in hd:
    plt.figure(figsize=(15,10))
    plt.title(("hidden="+str(i)))
    plt.grid()
    for p in pf:
        for m in mod:
            path = 'experiments_with_DP_95_/eval/LinearOneLayer{}/{}{}/curve.npz'.format(i,p,m)
            data = load(path)
            plt.plot(data['tr_err'] , label = (p+'_'+m))
            
    plt.legend()
    plt.show()

# %%
mod = ['lin_connect' , 'arc_connect']
pf = ['PointFinderWithBias' , 'PointFinderTransportation']
hd = [  10 ]
for i in hd:
    plt.figure(figsize=(15,10))
    plt.title(("hidden="+str(i)))
    plt.grid()
    for p in pf:
        for m in mod:
            path = 'experiments_with_DP_95_/eval/LinearOneLayer{}/{}{}/curve.npz'.format(i,p,m)
            data = load(path)
            plt.plot(data['tr_err'] , label = (p+'_'+m))
            
    plt.legend()
    plt.show()
