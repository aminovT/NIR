# %%
import matplotlib.pyplot as plt
from numpy import load

# %%
mod = ['lin_connect' , 'arc_connect']
pf = ['PointFinderWithBias', 'PointFinderInverseWithBias' , 'PointFinderTransportation']
hd = [ 10, 50, 100 , 500, 1000, 2000]
z = 0
for i in hd:
    for m in mod:
        for p in pf:
            z += 1
            if z !=2 and z!=5: 
                path = 'experiments_with_DP_50_/eval/LinearOneLayer{}/{}{}/curve.npz'.format(i,p,m)
                data = load(path)
                print(data['te_err_avg'] , data['te_err_max'] , i , p , m)
            else:
                print(path)
# Out:
# 19.96761904761905 41.21 10 PointFinderWithBias lin_connect
# experiments_with_DP_50_/eval/LinearOneLayer10/PointFinderWithBiaslin_connect/curve.npz
# 12.642380952380952 15.030000000000001 10 PointFinderTransportation lin_connect
# 18.409523809523808 28.75 10 PointFinderWithBias arc_connect
# experiments_with_DP_50_/eval/LinearOneLayer10/PointFinderWithBiasarc_connect/curve.npz
# 13.092380952380955 15.340000000000003 10 PointFinderTransportation arc_connect
# 7.677619047619046 14.170000000000002 50 PointFinderWithBias lin_connect
# 5.484285714285714 7.489999999999995 50 PointFinderInverseWithBias lin_connect
# 4.293333333333335 4.609999999999999 50 PointFinderTransportation lin_connect
# 7.5909523809523805 12.64 50 PointFinderWithBias arc_connect
# 5.656666666666665 7.430000000000007 50 PointFinderInverseWithBias arc_connect
# 4.4142857142857155 4.659999999999997 50 PointFinderTransportation arc_connect
# 5.267142857142859 9.680000000000007 100 PointFinderWithBias lin_connect
# 3.632857142857143 4.569999999999993 100 PointFinderInverseWithBias lin_connect
# 2.9590476190476203 3.0900000000000034 100 PointFinderTransportation lin_connect
# 5.17047619047619 8.290000000000006 100 PointFinderWithBias arc_connect
# 3.683809523809524 4.430000000000007 100 PointFinderInverseWithBias arc_connect
# 3.170952380952383 3.430000000000007 100 PointFinderTransportation arc_connect
# 2.591428571428572 3.569999999999993 500 PointFinderWithBias lin_connect
# 2.256190476190476 2.569999999999993 500 PointFinderInverseWithBias lin_connect
# 2.12190476190476 2.1700000000000017 500 PointFinderTransportation lin_connect
# 2.754761904761905 3.700000000000003 500 PointFinderWithBias arc_connect
# 2.2928571428571436 2.569999999999993 500 PointFinderInverseWithBias arc_connect
# 2.2085714285714295 2.280000000000001 500 PointFinderTransportation arc_connect
# 2.382857142857143 3.0999999999999943 1000 PointFinderWithBias lin_connect
# 2.0919047619047615 2.230000000000004 1000 PointFinderInverseWithBias lin_connect
# 1.9971428571428564 2.049999999999997 1000 PointFinderTransportation lin_connect
# 2.5542857142857143 3.3599999999999994 1000 PointFinderWithBias arc_connect
# 2.1071428571428585 2.230000000000004 1000 PointFinderInverseWithBias arc_connect
# 2.1542857142857152 2.2900000000000063 1000 PointFinderTransportation arc_connect
# 2.2214285714285715 2.75 2000 PointFinderWithBias lin_connect
# 1.9576190476190476 2.0600000000000023 2000 PointFinderInverseWithBias lin_connect
# 1.996666666666667 2.0900000000000034 2000 PointFinderTransportation lin_connect
# 2.2257142857142846 2.5999999999999943 2000 PointFinderWithBias arc_connect
# 1.9752380952380955 2.0900000000000034 2000 PointFinderInverseWithBias arc_connect
# 2.1228571428571428 2.25 2000 PointFinderTransportation arc_connect

# %%
mod = ['lin_connect' , 'arc_connect']
pf = ['PointFinderWithBias']#, 'PointFinderInverseWithBias' , 'PointFinderTransportation']
hd = [ 10, 50, 100 , 500, 1000, 2000]

for m in mod:
    plt.figure()
    plt.title(m)
    plt.grid()
    for p in pf:
        for i in hd:
            path = 'experiments_with_DP_50_/eval/LinearOneLayer{}/{}{}/curve.npz'.format(i,p,m)
            data = load(path)
            plt.plot(data['tr_err'] , label = str(i))
            
    plt.legend()
    plt.show()

# %%
mod = ['lin_connect' , 'arc_connect']
pf = [ 'PointFinderInverseWithBias' ]#, 'PointFinderTransportation']
hd = [  50, 100 , 500, 1000, 2000]

for m in mod:
    plt.figure()
    plt.title(("WA+"+m))
    plt.grid()
    for p in pf:
        for i in hd:
            path = 'experiments_with_DP_50_/eval/LinearOneLayer{}/{}{}/curve.npz'.format(i,p,m)
            data = load(path)
            plt.plot(data['tr_err'] , label = str(i))
            
    plt.legend()
    plt.show()

# %%
mod = ['lin_connect' , 'arc_connect']
pf = [ 'PointFinderTransportation']
hd = [  10, 50, 100 , 500, 1000, 2000]

for m in mod:
    plt.figure()
    plt.title(("OT+"+m))
    plt.grid()
    for p in pf:
        for i in hd:
            path = 'experiments_with_DP_50_/eval/LinearOneLayer{}/{}{}/curve.npz'.format(i,p,m)
            data = load(path)
            plt.plot(data['tr_err'] , label = str(i))
            
    plt.legend()
    plt.show()

# %%
mod = ['lin_connect' , 'arc_connect']
pf = ['PointFinderWithBias', 'PointFinderInverseWithBias' , 'PointFinderTransportation']
hd = [  50, 100 , 500, 1000, 2000]
for i in hd:
    plt.figure(figsize=(15,10))
    plt.title(("hidden="+str(i)))
    plt.grid()
    for p in pf:
        for m in mod:
            path = 'experiments_with_DP_50_/eval/LinearOneLayer{}/{}{}/curve.npz'.format(i,p,m)
            data = load(path)
            plt.plot(data['tr_err'] , label = (p+'_'+m))
            
    plt.legend()
    plt.show()

# %%
mod = ['lin_connect' , 'arc_connect']
pf = ['PointFinderWithBias' , 'PointFinderTransportation']
hd = [  10 ]
for i in hd:
    plt.figure(figsize=(15,10))
    plt.title(("hidden="+str(i)))
    plt.grid()
    for p in pf:
        for m in mod:
            path = 'experiments_with_DP_50_/eval/LinearOneLayer{}/{}{}/curve.npz'.format(i,p,m)
            data = load(path)
            plt.plot(data['tr_err'] , label = (p+'_'+m))
            
    plt.legend()
    plt.show()
