# %%
import matplotlib.pyplot as plt
from numpy import load

# %%
mod = ['lin_connect' , 'arc_connect']
pf = ['PointFinderWithBias', 'PointFinderInverseWithBias' , 'PointFinderTransportation']
hd = [ 10, 50, 100 , 500, 1000, 2000]
z = 0
for i in hd:
    for m in mod:
        for p in pf:
            z += 1
            if z !=2 and z!=5: 
                path = 'experiments_without_bias/eval/LinearOneLayer{}/{}{}/curve.npz'.format(i,p,m)
                data = load(path)
                print(data['te_err_avg'] , data['te_err_max'] , i , p , m)
            else:
                print(path)
# Out:
# 25.230952380952377 45.74 10 PointFinderWithBias lin_connect
# experiments_without_bias/eval/LinearOneLayer10/PointFinderWithBiaslin_connect/curve.npz
# 9.373333333333331 12.920000000000002 10 PointFinderTransportation lin_connect
# 21.10285714285714 35.94 10 PointFinderWithBias arc_connect
# experiments_without_bias/eval/LinearOneLayer10/PointFinderWithBiasarc_connect/curve.npz
# 10.283333333333333 13.769999999999996 10 PointFinderTransportation arc_connect
# 11.611428571428572 24.349999999999994 50 PointFinderWithBias lin_connect
# 4.189047619047619 5.909999999999997 50 PointFinderInverseWithBias lin_connect
# 3.471904761904761 4.019999999999996 50 PointFinderTransportation lin_connect
# 11.66952380952381 21.58 50 PointFinderWithBias arc_connect
# 4.287619047619046 5.769999999999996 50 PointFinderInverseWithBias arc_connect
# 3.8904761904761904 4.810000000000002 50 PointFinderTransportation arc_connect
# 5.446666666666666 10.829999999999998 100 PointFinderWithBias lin_connect
# 3.054285714285715 3.7900000000000063 100 PointFinderInverseWithBias lin_connect
# 2.648571428571428 2.8599999999999994 100 PointFinderTransportation lin_connect
# 5.462380952380952 9.530000000000001 100 PointFinderWithBias arc_connect
# 3.1099999999999994 3.7099999999999937 100 PointFinderInverseWithBias arc_connect
# 3.011428571428571 3.5 100 PointFinderTransportation arc_connect
# 3.142380952380952 4.840000000000003 500 PointFinderWithBias lin_connect
# 2.267142857142857 2.4599999999999937 500 PointFinderInverseWithBias lin_connect
# 2.2380952380952372 2.3799999999999955 500 PointFinderTransportation lin_connect
# 3.054761904761906 4.209999999999994 500 PointFinderWithBias arc_connect
# 2.2709523809523824 2.430000000000007 500 PointFinderInverseWithBias arc_connect
# 2.411904761904762 2.5900000000000034 500 PointFinderTransportation arc_connect
# 2.6423809523809534 3.8299999999999983 1000 PointFinderWithBias lin_connect
# 2.1061904761904744 2.239999999999995 1000 PointFinderInverseWithBias lin_connect
# 2.0604761904761895 2.1099999999999994 1000 PointFinderTransportation lin_connect
# 2.5600000000000014 3.3900000000000006 1000 PointFinderWithBias arc_connect
# 2.1209523809523807 2.230000000000004 1000 PointFinderInverseWithBias arc_connect
# 2.229047619047619 2.3599999999999994 1000 PointFinderTransportation arc_connect
# 2.788095238095237 4.170000000000002 2000 PointFinderWithBias lin_connect
# 2.036190476190476 2.1099999999999994 2000 PointFinderInverseWithBias lin_connect
# 2.1142857142857148 2.239999999999995 2000 PointFinderTransportation lin_connect
# 2.4271428571428566 2.980000000000004 2000 PointFinderWithBias arc_connect
# 2.0385714285714265 2.1099999999999994 2000 PointFinderInverseWithBias arc_connect
# 2.227142857142857 2.3700000000000045 2000 PointFinderTransportation arc_connect

# %%
mod = ['lin_connect' , 'arc_connect']
pf = ['PointFinderWithBias'] #, 'PointFinderInverseWithBias' , 'PointFinderTransportation']
hd = [ 10, 50, 100 , 500, 1000, 2000]

for m in mod:
    plt.figure()
    plt.title(m)
    plt.grid()
    for p in pf:
        for i in hd:
            path = 'experiments_without_bias/eval/LinearOneLayer{}/{}{}/curve.npz'.format(i,p,m)
            data = load(path)
            plt.plot(data['tr_err'] , label = str(i))
            
    plt.legend()
    plt.show()

# %%
mod = ['lin_connect' , 'arc_connect']
pf = [ 'PointFinderInverseWithBias' ]#, 'PointFinderTransportation']
hd = [  50, 100 , 500, 1000, 2000]

for m in mod:
    plt.figure()
    plt.title(("WA+"+m))
    plt.grid()
    for p in pf:
        for i in hd:
            path = 'experiments_without_bias/eval/LinearOneLayer{}/{}{}/curve.npz'.format(i,p,m)
            data = load(path)
            plt.plot(data['tr_err'] , label = str(i))
            
    plt.legend()
    plt.show()

# %%
mod = ['lin_connect' , 'arc_connect']
pf = [ 'PointFinderTransportation']
hd = [  10, 50, 100 , 500, 1000, 2000]

for m in mod:
    plt.figure()
    plt.title(("OT+"+m))
    plt.grid()
    for p in pf:
        for i in hd:
            path = 'experiments_without_bias/eval/LinearOneLayer{}/{}{}/curve.npz'.format(i,p,m)
            data = load(path)
            plt.plot(data['tr_err'] , label = str(i))
            
    plt.legend()
    plt.show()

# %%
mod = ['lin_connect' , 'arc_connect']
pf = ['PointFinderWithBias', 'PointFinderInverseWithBias' , 'PointFinderTransportation']
hd = [  50, 100 , 500, 1000, 2000]
for i in hd:
    plt.figure(figsize=(15,10))
    plt.title(("hidden="+str(i)))
    plt.grid()
    for p in pf:
        for m in mod:
            path = 'experiments_without_bias/eval/LinearOneLayer{}/{}{}/curve.npz'.format(i,p,m)
            data = load(path)
            plt.plot(data['tr_err'] , label = (p+'_'+m))
            
    plt.legend()
    plt.show()

# %%
mod = ['lin_connect' , 'arc_connect']
pf = ['PointFinderWithBias' , 'PointFinderTransportation']
hd = [  10 ]
for i in hd:
    plt.figure(figsize=(15,10))
    plt.title(("hidden="+str(i)))
    plt.grid()
    for p in pf:
        for m in mod:
            path = 'experiments/eval/LinearOneLayer{}/{}{}/curve.npz'.format(i,p,m)
            data = load(path)
            plt.plot(data['tr_err'] , label = (p+'_'+m))
            
    plt.legend()
    plt.show()
